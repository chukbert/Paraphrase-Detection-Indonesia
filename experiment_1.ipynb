# %%
import pandas as pd

feat_exp_1_total_test = pd.read_csv('data/features/feat_test_total_msrp.csv')
feat_exp_1_100_test = pd.read_csv('data/features/feat_test_100_total_msrp.csv')

feat_test_total = pd.concat([feat_exp_1_total_test, feat_exp_1_100_test], axis=0, ignore_index=True)
feat_test_total.to_csv('data/features/feat_test_total_msrp.csv', index=False)

# %% [markdown]
# # Data

# %%
import pandas as pd

msrp_train_df = pd.read_csv('data/features/feat_exp_1_msrp_old.csv')
total_train_df = pd.read_csv('data/features/feat_exp_1_msrp_paws_old.csv')
paws_train_df = total_train_df.iloc[4076:].copy()
paws_train_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Data MSRP only

# %%
data_train = msrp_train_df.copy()
X_train = data_train.drop(columns=['label'])
y_train = data_train['label']

# %%
import classifiers.svm as svm

gs_svm, model_svm = svm.find_best_param_svm(X_train, y_train, n_trials=200)
# Out:
# [I 2024-08-01 14:51:56,789] A new study created in memory with name: no-name-b1dfb3aa-c2cb-4b7f-9a12-41f785e5308a
# [I 2024-08-01 14:52:02,009] Trial 0 finished with value: 0.6585783444649671 and parameters: {'svc__C': 1.0, 'svc__kernel': 'linear', 'svc__gamma': 1.0, 'svc__degree': 3}. Best is trial 0 with value: 0.6585783444649671.
# [I 2024-08-01 14:52:06,278] Trial 1 finished with value: 0.6649187312470769 and parameters: {'svc__C': 0.8533277275014391, 'svc__kernel': 'rbf', 'svc__gamma': 0.0001375638593972196, 'svc__degree': 3}. Best is trial 1 with value: 0.6649187312470769.
# [I 2024-08-01 14:52:08,302] Trial 2 finished with value: 0.5260190367053383 and parameters: {'svc__C': 0.0014392373822650463, 'svc__kernel': 'poly', 'svc__gamma': 0.0014864433017692377, 'svc__degree': 2}. Best is trial 1 with value: 0.6649187312470769.
# ...

# %%
import classifiers.svm as svm

best_param_svm = {'svc__C': 0.6967897346979598, 'svc__kernel': 'rbf', 'svc__gamma': 0.001, 'svc__degree': 3}
best_param_svm = {k:[v] for k,v in best_param_svm.items()}
gs_svm, model_svm= svm.fit_train_svm(X_train, y_train, best_param_svm)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END svc__C=0.6967897346979598, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf; total time=   1.5s
# [CV] END svc__C=0.6967897346979598, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf; total time=   1.9s
# [CV] END svc__C=0.6967897346979598, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=0.6967897346979598, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=0.6967897346979598, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf; total time=   1.1s
# Akurasi: 0.689
# Presisi: 0.662
# Recall: 0.678
# F1 validasi: 0.665
# Confusion Matrix:
# [[172  93]
#  [161 390]]

# %%
best_param_firas = {'svc__C': 1.0, 'svc__kernel': 'linear', 'svc__gamma': 1.0, 'svc__degree': 3}
best_param_firas = {k:[v] for k,v in best_param_firas.items()}
gs_svm, model_svm= svm.fit_train_svm(X_train, y_train, best_param_firas)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END svc__C=1.0, svc__degree=3, svc__gamma=1.0, svc__kernel=linear; total time=   0.4s
# [CV] END svc__C=1.0, svc__degree=3, svc__gamma=1.0, svc__kernel=linear; total time=   0.4s
# [CV] END svc__C=1.0, svc__degree=3, svc__gamma=1.0, svc__kernel=linear; total time=   0.4s
# [CV] END svc__C=1.0, svc__degree=3, svc__gamma=1.0, svc__kernel=linear; total time=   0.7s
# [CV] END svc__C=1.0, svc__degree=3, svc__gamma=1.0, svc__kernel=linear; total time=   0.6s
# Akurasi: 0.657
# Presisi: 0.654
# Recall: 0.675
# F1 validasi: 0.645
# Confusion Matrix:
# [[193  72]
#  [208 343]]

# %%
import classifiers.xgb as xgb

gs_xgb, model_xgb = xgb.find_best_param_xgb(X_train, y_train, n_trials=200)
# Out:
# [I 2024-08-01 15:17:03,493] A new study created in memory with name: no-name-c397ac82-72df-4cab-8887-e31c53ed047f
# [I 2024-08-01 15:17:07,338] Trial 0 finished with value: 0.6358399048024055 and parameters: {'xgbclassifier__eta': 0.3, 'xgbclassifier__n_estimators': 100, 'xgbclassifier__max_depth': 6, 'xgbclassifier__learning_rate': 0.3, 'xgbclassifier__subsample': 1.0, 'xgbclassifier__colsample_bytree': 1.0, 'xgbclassifier__min_child_weight': 1, 'xgbclassifier__gamma': 0.0, 'xgbclassifier__reg_lambda': 1.0, 'xgbclassifier__objective': 'reg:squarederror'}. Best is trial 0 with value: 0.6358399048024055.
# ...

# %%
import classifiers.xgb as xgb

best_param_xgb = {'xgbclassifier__eta': 0.10956403322577613, 'xgbclassifier__n_estimators': 389, 'xgbclassifier__max_depth': 4, 'xgbclassifier__learning_rate': 0.011943270788670229, 'xgbclassifier__subsample': 0.5322246273506048, 'xgbclassifier__colsample_bytree': 0.7645849850697513, 'xgbclassifier__min_child_weight': 4, 'xgbclassifier__gamma': 3.407729229089508, 'xgbclassifier__reg_lambda': 3.419721702364318, 'xgbclassifier__objective': 'binary:hinge'}
best_param_xgb = {k:[v] for k,v in best_param_xgb.items()}
gs_xgb, model_xgb= xgb.fit_train_xgb(X_train, y_train, param=best_param_xgb)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END xgbclassifier__colsample_bytree=0.7645849850697513, xgbclassifier__eta=0.10956403322577613, xgbclassifier__gamma=3.407729229089508, xgbclassifier__learning_rate=0.011943270788670229, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=4, xgbclassifier__n_estimators=389, xgbclassifier__objective=binary:hinge, xgbclassifier__reg_lambda=3.419721702364318, xgbclassifier__subsample=0.5322246273506048; total time=   1.4s
# [CV] END xgbclassifier__colsample_bytree=0.7645849850697513, xgbclassifier__eta=0.10956403322577613, xgbclassifier__gamma=3.407729229089508, xgbclassifier__learning_rate=0.011943270788670229, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=4, xgbclassifier__n_estimators=389, xgbclassifier__objective=binary:hinge, xgbclassifier__reg_lambda=3.419721702364318, xgbclassifier__subsample=0.5322246273506048; total time=   0.2s
# ...

# %%
import classifiers.xgb as xgb

best_param_xgb = {'xgbclassifier__eta': 0.10956403322577613, 'xgbclassifier__n_estimators': 389, 'xgbclassifier__max_depth': 4, 'xgbclassifier__learning_rate': 0.011943270788670229, 'xgbclassifier__subsample': 0.5322246273506048, 'xgbclassifier__colsample_bytree': 0.7645849850697513, 'xgbclassifier__min_child_weight': 4, 'xgbclassifier__gamma': 3.407729229089508, 'xgbclassifier__reg_lambda': 3.419721702364318, 'xgbclassifier__objective': 'binary:hinge'}
best_param_xgb = {k:[v] for k,v in best_param_xgb.items()}
gs_xgb, model_xgb= xgb.fit_train_xgb(X_train, y_train, param=best_param_xgb)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END xgbclassifier__colsample_bytree=0.7645849850697513, xgbclassifier__eta=0.10956403322577613, xgbclassifier__gamma=3.407729229089508, xgbclassifier__learning_rate=0.011943270788670229, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=4, xgbclassifier__n_estimators=389, xgbclassifier__objective=binary:hinge, xgbclassifier__reg_lambda=3.419721702364318, xgbclassifier__subsample=0.5322246273506048; total time=   0.3s
# [CV] END xgbclassifier__colsample_bytree=0.7645849850697513, xgbclassifier__eta=0.10956403322577613, xgbclassifier__gamma=3.407729229089508, xgbclassifier__learning_rate=0.011943270788670229, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=4, xgbclassifier__n_estimators=389, xgbclassifier__objective=binary:hinge, xgbclassifier__reg_lambda=3.419721702364318, xgbclassifier__subsample=0.5322246273506048; total time=   0.2s
# ...

# %%
import classifiers.rf as rf
gs_rf, model_rf = rf.find_best_param_rf(X_train, y_train)
# Out:
# [I 2024-06-20 17:50:52,784] A new study created in memory with name: no-name-c0a2e7f8-a1d5-49d8-be32-9740a4f8c521
# [I 2024-06-20 17:50:55,442] Trial 0 finished with value: 0.6399885367241656 and parameters: {'randomforestclassifier__n_estimators': 100, 'randomforestclassifier__max_features': 'sqrt', 'randomforestclassifier__max_depth': 100, 'randomforestclassifier__criterion': 'gini', 'randomforestclassifier__max_leaf_nodes': 1000, 'randomforestclassifier__bootstrap': True}. Best is trial 0 with value: 0.6399885367241656.
# [I 2024-06-20 17:51:00,831] Trial 1 finished with value: 0.6702355347953131 and parameters: {'randomforestclassifier__n_estimators': 387, 'randomforestclassifier__max_features': 'sqrt', 'randomforestclassifier__max_depth': 17, 'randomforestclassifier__criterion': 'gini', 'randomforestclassifier__max_leaf_nodes': 10, 'randomforestclassifier__bootstrap': False}. Best is trial 1 with value: 0.6702355347953131.
# ...

# %%
import classifiers.rf as rf

param = {'randomforestclassifier__n_estimators': 387, 'randomforestclassifier__max_features': 'sqrt', 'randomforestclassifier__max_depth': 17, 'randomforestclassifier__criterion': 'gini', 'randomforestclassifier__max_leaf_nodes': 10, 'randomforestclassifier__bootstrap': False}
param = {k: [v] for k,v in param.items()}
gs, model = rf.fit_train_rf(X_train, y_train, param=param)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END randomforestclassifier__bootstrap=False, randomforestclassifier__criterion=gini, randomforestclassifier__max_depth=17, randomforestclassifier__max_features=sqrt, randomforestclassifier__max_leaf_nodes=10, randomforestclassifier__n_estimators=387; total time=   3.2s
# [CV] END randomforestclassifier__bootstrap=False, randomforestclassifier__criterion=gini, randomforestclassifier__max_depth=17, randomforestclassifier__max_features=sqrt, randomforestclassifier__max_leaf_nodes=10, randomforestclassifier__n_estimators=387; total time=   3.0s
# [CV] END randomforestclassifier__bootstrap=False, randomforestclassifier__criterion=gini, randomforestclassifier__max_depth=17, randomforestclassifier__max_features=sqrt, randomforestclassifier__max_leaf_nodes=10, randomforestclassifier__n_estimators=387; total time=   3.1s
# ...

# %%
import classifiers.lgbm as lgbm

param = {'lgbmclassifier__num_leaves': 89, 'lgbmclassifier__min_data_in_leaf': 14, 'lgbmclassifier__max_depth': 8, 'lgbmclassifier__learning_rate': 0.07552182221074541, 'lgbmclassifier__n_estimators': 34, 'lgbmclassifier__subsample': 0.6513231700945394, 'lgbmclassifier__colsample_bytree': 0.5461699694505303, 'lgbmclassifier__reg_alpha': 5.698510176625059, 'lgbmclassifier__reg_lambda': 8.33433348437254, 'lgbmclassifier__boosting': 'gbdt'}
param = {k: [v] for k,v in param.items()}
gs, model = lgbm.fit_train_lgbm(X_train, y_train, param)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END lgbmclassifier__boosting=gbdt, lgbmclassifier__colsample_bytree=0.5461699694505303, lgbmclassifier__learning_rate=0.07552182221074541, lgbmclassifier__max_depth=8, lgbmclassifier__min_data_in_leaf=14, lgbmclassifier__n_estimators=34, lgbmclassifier__num_leaves=89, lgbmclassifier__reg_alpha=5.698510176625059, lgbmclassifier__reg_lambda=8.33433348437254, lgbmclassifier__subsample=0.6513231700945394; total time=   0.1s
# [CV] END lgbmclassifier__boosting=gbdt, lgbmclassifier__colsample_bytree=0.5461699694505303, lgbmclassifier__learning_rate=0.07552182221074541, lgbmclassifier__max_depth=8, lgbmclassifier__min_data_in_leaf=14, lgbmclassifier__n_estimators=34, lgbmclassifier__num_leaves=89, lgbmclassifier__reg_alpha=5.698510176625059, lgbmclassifier__reg_lambda=8.33433348437254, lgbmclassifier__subsample=0.6513231700945394; total time=   0.1s
# ...

# %% [markdown]
# # PAWS ONLY

# %%
data_train = paws_train_df.copy()
X_train = data_train.drop(columns=['label'])
y_train = data_train['label']

# %%
import classifiers.svm as svm

best_param_svm = {'svc__C': 1.0, 'svc__kernel': 'linear', 'svc__gamma': 1.0, 'svc__degree': 3}
best_param_svm = {k:[v] for k,v in best_param_svm.items()}
gs_svm, model_svm= svm.fit_train_svm(X_train, y_train, best_param_svm)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END svc__C=1.0, svc__degree=3, svc__gamma=1.0, svc__kernel=linear; total time=  58.9s
# [CV] END svc__C=1.0, svc__degree=3, svc__gamma=1.0, svc__kernel=linear; total time= 1.0min
# [CV] END svc__C=1.0, svc__degree=3, svc__gamma=1.0, svc__kernel=linear; total time= 1.1min
# [CV] END svc__C=1.0, svc__degree=3, svc__gamma=1.0, svc__kernel=linear; total time= 1.2min
# [CV] END svc__C=1.0, svc__degree=3, svc__gamma=1.0, svc__kernel=linear; total time= 1.2min
# Akurasi: 0.651
# Presisi: 0.651
# Recall: 0.653
# F1 validasi: 0.650
# Confusion Matrix:
# [[3498 2065]
#  [1416 2984]]

# %%
import classifiers.xgb as xgb
param = {'xgbclassifier__eta': 0.14618751680299752, 'xgbclassifier__n_estimators': 645, 'xgbclassifier__max_depth': 10, 'xgbclassifier__learning_rate': 0.014496810172055365, 'xgbclassifier__subsample': 0.6160084934068276, 'xgbclassifier__colsample_bytree': 0.9506368096010325, 'xgbclassifier__min_child_weight': 9, 'xgbclassifier__gamma': 0.9411859017668444, 'xgbclassifier__reg_lambda': 4.518974576320344, 'xgbclassifier__objective': 'reg:squarederror'}
param = {k: [v] for k,v in param.items()}
gs, model = xgb.fit_train_xgb(X_train, y_train, param)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END xgbclassifier__colsample_bytree=0.9506368096010325, xgbclassifier__eta=0.14618751680299752, xgbclassifier__gamma=0.9411859017668444, xgbclassifier__learning_rate=0.014496810172055365, xgbclassifier__max_depth=10, xgbclassifier__min_child_weight=9, xgbclassifier__n_estimators=645, xgbclassifier__objective=reg:squarederror, xgbclassifier__reg_lambda=4.518974576320344, xgbclassifier__subsample=0.6160084934068276; total time=   1.2s
# [CV] END xgbclassifier__colsample_bytree=0.9506368096010325, xgbclassifier__eta=0.14618751680299752, xgbclassifier__gamma=0.9411859017668444, xgbclassifier__learning_rate=0.014496810172055365, xgbclassifier__max_depth=10, xgbclassifier__min_child_weight=9, xgbclassifier__n_estimators=645, xgbclassifier__objective=reg:squarederror, xgbclassifier__reg_lambda=4.518974576320344, xgbclassifier__subsample=0.6160084934068276; total time=   2.2s
# ...

# %%
import classifiers.rf as rf

param = {'randomforestclassifier__n_estimators': 387, 'randomforestclassifier__max_features': None, 'randomforestclassifier__max_depth': 39, 'randomforestclassifier__criterion': 'entropy', 'randomforestclassifier__max_leaf_nodes': 128, 'randomforestclassifier__bootstrap': True}
param = {k: [v] for k,v in param.items()}
gs, model = rf.fit_train_rf(X_train, y_train, param)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END randomforestclassifier__bootstrap=True, randomforestclassifier__criterion=entropy, randomforestclassifier__max_depth=39, randomforestclassifier__max_features=None, randomforestclassifier__max_leaf_nodes=128, randomforestclassifier__n_estimators=387; total time= 1.2min
# [CV] END randomforestclassifier__bootstrap=True, randomforestclassifier__criterion=entropy, randomforestclassifier__max_depth=39, randomforestclassifier__max_features=None, randomforestclassifier__max_leaf_nodes=128, randomforestclassifier__n_estimators=387; total time= 1.2min
# [CV] END randomforestclassifier__bootstrap=True, randomforestclassifier__criterion=entropy, randomforestclassifier__max_depth=39, randomforestclassifier__max_features=None, randomforestclassifier__max_leaf_nodes=128, randomforestclassifier__n_estimators=387; total time= 1.2min
# ...

# %%
import classifiers.lgbm as lgbm

param = {'lgbmclassifier__num_leaves': 96, 'lgbmclassifier__min_data_in_leaf': 62, 'lgbmclassifier__max_depth': 4, 'lgbmclassifier__learning_rate': 0.09273378742652472, 'lgbmclassifier__n_estimators': 339, 'lgbmclassifier__subsample': 0.8486295975701159, 'lgbmclassifier__colsample_bytree': 0.8907649475648106, 'lgbmclassifier__reg_alpha': 7.263603604786825, 'lgbmclassifier__reg_lambda': 4.510289185173246, 'lgbmclassifier__boosting': 'dart'}
param = {k: [v] for k,v in param.items()}
gs, model = lgbm.fit_train_lgbm(X_train, y_train, param)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END lgbmclassifier__boosting=dart, lgbmclassifier__colsample_bytree=0.8907649475648106, lgbmclassifier__learning_rate=0.09273378742652472, lgbmclassifier__max_depth=4, lgbmclassifier__min_data_in_leaf=62, lgbmclassifier__n_estimators=339, lgbmclassifier__num_leaves=96, lgbmclassifier__reg_alpha=7.263603604786825, lgbmclassifier__reg_lambda=4.510289185173246, lgbmclassifier__subsample=0.8486295975701159; total time=   8.1s
# [CV] END lgbmclassifier__boosting=dart, lgbmclassifier__colsample_bytree=0.8907649475648106, lgbmclassifier__learning_rate=0.09273378742652472, lgbmclassifier__max_depth=4, lgbmclassifier__min_data_in_leaf=62, lgbmclassifier__n_estimators=339, lgbmclassifier__num_leaves=96, lgbmclassifier__reg_alpha=7.263603604786825, lgbmclassifier__reg_lambda=4.510289185173246, lgbmclassifier__subsample=0.8486295975701159; total time=   7.6s
# ...

# %% [markdown]
# # TOTAL

# %%
data_train = total_train_df.copy()
X_train = data_train.drop(columns=['label'])
y_train = data_train['label']

# %%
import classifiers.svm as svm

best_param_svm = {'svc__C': 1.0, 'svc__kernel': 'linear', 'svc__gamma': 1.0, 'svc__degree': 3}
best_param_svm = {k:[v] for k,v in best_param_svm.items()}
gs_svm, model_svm= svm.fit_train_svm(X_train, y_train, best_param_svm)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END svc__C=1.0, svc__degree=3, svc__gamma=1.0, svc__kernel=linear; total time= 1.2min
# [CV] END svc__C=1.0, svc__degree=3, svc__gamma=1.0, svc__kernel=linear; total time= 1.6min
# [CV] END svc__C=1.0, svc__degree=3, svc__gamma=1.0, svc__kernel=linear; total time= 1.4min
# [CV] END svc__C=1.0, svc__degree=3, svc__gamma=1.0, svc__kernel=linear; total time= 1.4min
# [CV] END svc__C=1.0, svc__degree=3, svc__gamma=1.0, svc__kernel=linear; total time= 1.2min
# Akurasi: 0.614
# Presisi: 0.615
# Recall: 0.616
# F1 validasi: 0.613
# Confusion Matrix:
# [[3432 2396]
#  [1768 3182]]

# %%
param = {'xgbclassifier__eta': 0.20037472954333604, 'xgbclassifier__n_estimators': 773, 'xgbclassifier__max_depth': 9, 'xgbclassifier__learning_rate': 0.09888296769184594, 'xgbclassifier__subsample': 0.7376883883675472, 'xgbclassifier__colsample_bytree': 0.80454431383597, 'xgbclassifier__min_child_weight': 2, 'xgbclassifier__gamma': 1.383374448967123, 'xgbclassifier__reg_lambda': 7.2174892286583425, 'xgbclassifier__objective': 'reg:squarederror'}
param = {k: [v] for k,v in param.items()}
gs, model = xgb.fit_train_xgb(X_train, y_train, param)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END xgbclassifier__colsample_bytree=0.80454431383597, xgbclassifier__eta=0.20037472954333604, xgbclassifier__gamma=1.383374448967123, xgbclassifier__learning_rate=0.09888296769184594, xgbclassifier__max_depth=9, xgbclassifier__min_child_weight=2, xgbclassifier__n_estimators=773, xgbclassifier__objective=reg:squarederror, xgbclassifier__reg_lambda=7.2174892286583425, xgbclassifier__subsample=0.7376883883675472; total time=   1.3s
# [CV] END xgbclassifier__colsample_bytree=0.80454431383597, xgbclassifier__eta=0.20037472954333604, xgbclassifier__gamma=1.383374448967123, xgbclassifier__learning_rate=0.09888296769184594, xgbclassifier__max_depth=9, xgbclassifier__min_child_weight=2, xgbclassifier__n_estimators=773, xgbclassifier__objective=reg:squarederror, xgbclassifier__reg_lambda=7.2174892286583425, xgbclassifier__subsample=0.7376883883675472; total time=   1.7s
# ...

# %%
param = {'randomforestclassifier__n_estimators': 654, 'randomforestclassifier__max_features': 'log2', 'randomforestclassifier__max_depth': 11, 'randomforestclassifier__criterion': 'entropy', 'randomforestclassifier__max_leaf_nodes': 811, 'randomforestclassifier__bootstrap': True}
param = {k: [v] for k,v in param.items()}
gs, model = rf.fit_train_rf(X_train, y_train, param)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END randomforestclassifier__bootstrap=True, randomforestclassifier__criterion=entropy, randomforestclassifier__max_depth=11, randomforestclassifier__max_features=log2, randomforestclassifier__max_leaf_nodes=811, randomforestclassifier__n_estimators=654; total time= 1.3min
# [CV] END randomforestclassifier__bootstrap=True, randomforestclassifier__criterion=entropy, randomforestclassifier__max_depth=11, randomforestclassifier__max_features=log2, randomforestclassifier__max_leaf_nodes=811, randomforestclassifier__n_estimators=654; total time= 1.4min
# [CV] END randomforestclassifier__bootstrap=True, randomforestclassifier__criterion=entropy, randomforestclassifier__max_depth=11, randomforestclassifier__max_features=log2, randomforestclassifier__max_leaf_nodes=811, randomforestclassifier__n_estimators=654; total time= 1.3min
# ...

# %%
param = {'lgbmclassifier__num_leaves': 34, 'lgbmclassifier__min_data_in_leaf': 14, 'lgbmclassifier__max_depth': 10, 'lgbmclassifier__learning_rate': 0.028517778276614992, 'lgbmclassifier__n_estimators': 359, 'lgbmclassifier__subsample': 0.523199022379447, 'lgbmclassifier__colsample_bytree': 0.882952454485044, 'lgbmclassifier__reg_alpha': 4.996010675682532, 'lgbmclassifier__reg_lambda': 1.1195700130898794, 'lgbmclassifier__boosting': 'gbdt'}
param = {k: [v] for k,v in param.items()}
gs, model = lgbm.fit_train_lgbm(X_train, y_train, param)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END lgbmclassifier__boosting=gbdt, lgbmclassifier__colsample_bytree=0.882952454485044, lgbmclassifier__learning_rate=0.028517778276614992, lgbmclassifier__max_depth=10, lgbmclassifier__min_data_in_leaf=14, lgbmclassifier__n_estimators=359, lgbmclassifier__num_leaves=34, lgbmclassifier__reg_alpha=4.996010675682532, lgbmclassifier__reg_lambda=1.1195700130898794, lgbmclassifier__subsample=0.523199022379447; total time=   3.1s
# [CV] END lgbmclassifier__boosting=gbdt, lgbmclassifier__colsample_bytree=0.882952454485044, lgbmclassifier__learning_rate=0.028517778276614992, lgbmclassifier__max_depth=10, lgbmclassifier__min_data_in_leaf=14, lgbmclassifier__n_estimators=359, lgbmclassifier__num_leaves=34, lgbmclassifier__reg_alpha=4.996010675682532, lgbmclassifier__reg_lambda=1.1195700130898794, lgbmclassifier__subsample=0.523199022379447; total time=   1.8s
# ...
