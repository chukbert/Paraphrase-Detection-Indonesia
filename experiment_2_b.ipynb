# %% [markdown]
# # SMATCH ONLY

# %%
import pandas as pd

train_df = pd.read_csv('data/features/feat_train_total_msrp.csv')
train_df_new = pd.read_csv('data/features/feat_exp_1_msrp.csv')

# %%
train_df = train_df[['feat_smatch', 'label']]
train_df_new = train_df_new[['feat_smatch', 'label']]

# %%
train = train_df.copy()
X_train = train.drop(columns=['label'])
y_train = train['label']

# %%
train_new = train_df_new.copy()
X_train_new = train_new.drop(columns=['label'])
y_train_new = train_new['label']

# %%
gs, model = find_best_param_svm(X_train, y_train)
# Out:
# [I 2024-06-20 21:47:14,048] A new study created in memory with name: no-name-225a9f8b-108f-4aee-9269-276f875e95af
# [I 2024-06-20 21:47:19,167] Trial 0 finished with value: 0.569933041818137 and parameters: {'svc__C': 1.0, 'svc__kernel': 'linear', 'svc__gamma': 1.0, 'svc__degree': 3}. Best is trial 0 with value: 0.569933041818137.
# [I 2024-06-20 21:47:23,612] Trial 1 finished with value: 0.5646153083709142 and parameters: {'svc__C': 0.6967897346979598, 'svc__kernel': 'rbf', 'svc__gamma': 0.001, 'svc__degree': 3}. Best is trial 0 with value: 0.569933041818137.
# [I 2024-06-20 21:47:26,705] Trial 2 finished with value: 0.4775903506302653 and parameters: {'svc__C': 0.0014466769693289958, 'svc__kernel': 'poly', 'svc__gamma': 4.038495593831462, 'svc__degree': 3}. Best is trial 0 with value: 0.569933041818137.
# ...

# %%
gs, model = find_best_param_svm(X_train, y_train)
# Out:
# [I 2024-06-20 21:52:44,009] A new study created in memory with name: no-name-60d91b2e-8d8f-40fe-91cf-7ea6bee6b149
# [I 2024-06-20 21:52:47,545] Trial 0 finished with value: 0.5698609154972062 and parameters: {'svc__C': 263.7551348331903, 'svc__kernel': 'linear', 'svc__gamma': 0.02960824406304236, 'svc__degree': 3}. Best is trial 0 with value: 0.5698609154972062.
# [I 2024-06-20 21:52:51,421] Trial 1 finished with value: 0.5698609154972062 and parameters: {'svc__C': 563.0974939062363, 'svc__kernel': 'linear', 'svc__gamma': 0.002667909190331825, 'svc__degree': 3}. Best is trial 0 with value: 0.5698609154972062.
# [I 2024-06-20 21:52:54,644] Trial 2 finished with value: 0.5699221339728417 and parameters: {'svc__C': 2.241040450105648, 'svc__kernel': 'rbf', 'svc__gamma': 0.004550600115636306, 'svc__degree': 3}. Best is trial 2 with value: 0.5699221339728417.
# ...

# %%
import classifiers.svm as svm

param = {'svc__C': 148.03469818134178, 'svc__kernel': 'rbf', 'svc__gamma': 0.013444516161810954, 'svc__degree': 3}
param = {k: [v] for k,v in param.items()}
_, _ = svm.fit_train_svm(X_train, y_train, param)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END svc__C=148.03469818134178, svc__degree=3, svc__gamma=0.013444516161810954, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=148.03469818134178, svc__degree=3, svc__gamma=0.013444516161810954, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=148.03469818134178, svc__degree=3, svc__gamma=0.013444516161810954, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=148.03469818134178, svc__degree=3, svc__gamma=0.013444516161810954, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=148.03469818134178, svc__degree=3, svc__gamma=0.013444516161810954, svc__kernel=rbf; total time=   1.2s
# Akurasi: 0.607
# Presisi: 0.611
# Recall: 0.626
# F1 validasi: 0.596
# Confusion Matrix:
# [[181  84]
#  [237 314]]

# %%
import classifiers.svm as svm

param = {'svc__C': 148.03469818134178, 'svc__kernel': 'rbf', 'svc__gamma': 0.013444516161810954, 'svc__degree': 3}
param = {k: [v] for k,v in param.items()}
_, model = svm.fit_train_svm(X_train, y_train, param)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END svc__C=148.03469818134178, svc__degree=3, svc__gamma=0.013444516161810954, svc__kernel=rbf; total time=   1.5s
# [CV] END svc__C=148.03469818134178, svc__degree=3, svc__gamma=0.013444516161810954, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=148.03469818134178, svc__degree=3, svc__gamma=0.013444516161810954, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=148.03469818134178, svc__degree=3, svc__gamma=0.013444516161810954, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=148.03469818134178, svc__degree=3, svc__gamma=0.013444516161810954, svc__kernel=rbf; total time=   1.2s
# Akurasi: 0.607
# Presisi: 0.611
# Recall: 0.626
# F1 validasi: 0.596
# Confusion Matrix:
# [[181  84]
#  [237 314]]

# %%
import joblib

joblib.dump(model, 'model/best_model_smatch.pkl')
# Out:
# ['model/best_model_smatch.pkl']

# %%
import joblib

from utils.evaluation_matrics import print_validasi
best_pipeline = joblib.load('model/best_model_smatch.pkl')

print_validasi(best_pipeline, X_train, y_train)
# Out:
# Akurasi: 0.607
# Presisi: 0.611
# Recall: 0.626
# F1 validasi: 0.596
# Confusion Matrix:
# [[181  84]
#  [237 314]]

# %%
import classifiers.svm as svm

param = {'svc__C': 148.03469818134178, 'svc__kernel': 'rbf', 'svc__gamma': 0.013444516161810954, 'svc__degree': 3}
param = {k: [v] for k,v in param.items()}
_, _ = svm.fit_train_svm(X_train_new, y_train_new, param)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END svc__C=148.03469818134178, svc__degree=3, svc__gamma=0.013444516161810954, svc__kernel=rbf; total time=   1.3s
# [CV] END svc__C=148.03469818134178, svc__degree=3, svc__gamma=0.013444516161810954, svc__kernel=rbf; total time=   1.3s
# [CV] END svc__C=148.03469818134178, svc__degree=3, svc__gamma=0.013444516161810954, svc__kernel=rbf; total time=   1.7s
# [CV] END svc__C=148.03469818134178, svc__degree=3, svc__gamma=0.013444516161810954, svc__kernel=rbf; total time=   1.3s
# [CV] END svc__C=148.03469818134178, svc__degree=3, svc__gamma=0.013444516161810954, svc__kernel=rbf; total time=   1.2s
# Akurasi: 0.594
# Presisi: 0.588
# Recall: 0.601
# F1 validasi: 0.579
# Confusion Matrix:
# [[164 101]
#  [230 321]]

# %%
gs, model = find_best_param_xgb(X_train, y_train, timeout=300)
# Out:
# [I 2024-06-20 21:59:28,175] A new study created in memory with name: no-name-751f5641-99db-4ebc-b00a-9bc36363ece6
# [I 2024-06-20 21:59:29,391] Trial 0 finished with value: 0.5315365845035842 and parameters: {'xgbclassifier__eta': 0.3, 'xgbclassifier__n_estimators': 100, 'xgbclassifier__max_depth': 6, 'xgbclassifier__learning_rate': 0.3, 'xgbclassifier__subsample': 1.0, 'xgbclassifier__colsample_bytree': 1.0, 'xgbclassifier__min_child_weight': 1, 'xgbclassifier__gamma': 0.0, 'xgbclassifier__reg_lambda': 1.0, 'xgbclassifier__objective': 'reg:squarederror'}. Best is trial 0 with value: 0.5315365845035842.
# ...

# %%
gs, model = find_best_param_xgb(X_train, y_train, timeout=300)
# Out:
# [I 2024-06-20 22:05:27,318] A new study created in memory with name: no-name-b23e26ea-a463-4913-bbb4-3ceffdb6ec23
# [I 2024-06-20 22:05:27,768] Trial 0 finished with value: 0.5796696431927062 and parameters: {'xgbclassifier__eta': 0.025120894844134368, 'xgbclassifier__n_estimators': 385, 'xgbclassifier__max_depth': 4, 'xgbclassifier__learning_rate': 0.01828781381715172, 'xgbclassifier__subsample': 0.5190934106483254, 'xgbclassifier__colsample_bytree': 0.8402196353179404, 'xgbclassifier__min_child_weight': 4, 'xgbclassifier__gamma': 3.1824716620129716, 'xgbclassifier__reg_lambda': 3.7047950807400096, 'xgbclassifier__objective': 'binary:hinge'}. Best is trial 0 with value: 0.5796696431927062.
# ...

# %%
import classifiers.xgb as xgb
gs, model = xgb.find_best_param_xgb(X_train_new, y_train_new, timeout=300)
# Out:
# [I 2024-08-01 17:00:02,044] A new study created in memory with name: no-name-8b182dd1-cb46-4019-84e2-279f9ced6bb3
# [I 2024-08-01 17:00:06,058] Trial 0 finished with value: 0.5550497942880048 and parameters: {'xgbclassifier__eta': 0.3, 'xgbclassifier__n_estimators': 100, 'xgbclassifier__max_depth': 6, 'xgbclassifier__learning_rate': 0.3, 'xgbclassifier__subsample': 1.0, 'xgbclassifier__colsample_bytree': 1.0, 'xgbclassifier__min_child_weight': 1, 'xgbclassifier__gamma': 0.0, 'xgbclassifier__reg_lambda': 1.0, 'xgbclassifier__objective': 'reg:squarederror'}. Best is trial 0 with value: 0.5550497942880048.
# ...

# %%
import classifiers.xgb as xgb

param = {'xgbclassifier__eta': 0.025120894844134368, 'xgbclassifier__n_estimators': 385, 'xgbclassifier__max_depth': 4, 'xgbclassifier__learning_rate': 0.01828781381715172, 'xgbclassifier__subsample': 0.5190934106483254, 'xgbclassifier__colsample_bytree': 0.8402196353179404, 'xgbclassifier__min_child_weight': 4, 'xgbclassifier__gamma': 3.1824716620129716, 'xgbclassifier__reg_lambda': 3.7047950807400096, 'xgbclassifier__objective': 'binary:hinge'}
param = {k: [v] for k,v in param.items()}
_, _ = xgb.fit_train_xgb(X_train, y_train, param)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END xgbclassifier__colsample_bytree=0.8402196353179404, xgbclassifier__eta=0.025120894844134368, xgbclassifier__gamma=3.1824716620129716, xgbclassifier__learning_rate=0.01828781381715172, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=4, xgbclassifier__n_estimators=385, xgbclassifier__objective=binary:hinge, xgbclassifier__reg_lambda=3.7047950807400096, xgbclassifier__subsample=0.5190934106483254; total time=   1.7s
# [CV] END xgbclassifier__colsample_bytree=0.8402196353179404, xgbclassifier__eta=0.025120894844134368, xgbclassifier__gamma=3.1824716620129716, xgbclassifier__learning_rate=0.01828781381715172, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=4, xgbclassifier__n_estimators=385, xgbclassifier__objective=binary:hinge, xgbclassifier__reg_lambda=3.7047950807400096, xgbclassifier__subsample=0.5190934106483254; total time=   0.4s
# ...

# %% [markdown]
# # RF

# %%
gs, model = find_best_param_rf(X_train, y_train, timeout=300)
# Out:
# [I 2024-06-22 21:39:27,480] A new study created in memory with name: no-name-e6fbb564-33b4-4e8f-a4d0-cd1b797587ee
# [I 2024-06-22 21:39:34,980] Trial 0 finished with value: 0.5368077000766498 and parameters: {'randomforestclassifier__n_estimators': 100, 'randomforestclassifier__max_features': 'sqrt', 'randomforestclassifier__max_depth': 100, 'randomforestclassifier__criterion': 'gini', 'randomforestclassifier__max_leaf_nodes': 1000, 'randomforestclassifier__bootstrap': True}. Best is trial 0 with value: 0.5368077000766498.
# [I 2024-06-22 21:39:53,222] Trial 1 finished with value: 0.5453757249564843 and parameters: {'randomforestclassifier__n_estimators': 922, 'randomforestclassifier__max_features': None, 'randomforestclassifier__max_depth': 94, 'randomforestclassifier__criterion': 'gini', 'randomforestclassifier__max_leaf_nodes': 87, 'randomforestclassifier__bootstrap': False}. Best is trial 1 with value: 0.5453757249564843.
# ...

# %%
gs, model = find_best_param_rf(X_train, y_train, timeout=300)
# Out:
# [I 2024-06-22 21:46:22,616] A new study created in memory with name: no-name-753841d1-e04c-4a3e-b21b-bc33e28cd852
# [I 2024-06-22 21:46:23,900] Trial 0 finished with value: 0.5368077000766498 and parameters: {'randomforestclassifier__n_estimators': 100, 'randomforestclassifier__max_features': 'sqrt', 'randomforestclassifier__max_depth': 100, 'randomforestclassifier__criterion': 'gini', 'randomforestclassifier__max_leaf_nodes': 1000, 'randomforestclassifier__bootstrap': True}. Best is trial 0 with value: 0.5368077000766498.
# [I 2024-06-22 21:46:34,545] Trial 1 finished with value: 0.5520892489111395 and parameters: {'randomforestclassifier__n_estimators': 997, 'randomforestclassifier__max_features': 'log2', 'randomforestclassifier__max_depth': 11, 'randomforestclassifier__criterion': 'entropy', 'randomforestclassifier__max_leaf_nodes': 46, 'randomforestclassifier__bootstrap': True}. Best is trial 1 with value: 0.5520892489111395.
# ...

# %%
import classifiers.rf as rf

list_param = [{'randomforestclassifier__n_estimators': 990, 'randomforestclassifier__max_features': 'log2', 'randomforestclassifier__max_depth': 10, 'randomforestclassifier__criterion': 'entropy', 'randomforestclassifier__max_leaf_nodes': 238, 'randomforestclassifier__bootstrap': True}]
gs, model = rf.find_best_param_rf(X_train, y_train, n_trials=100, timeout=300, list_param=list_param)
# Out:
# [I 2024-06-22 22:12:15,584] A new study created in memory with name: no-name-47b6f8b6-9d1a-47f2-98cc-3a7209ddbffa
# [I 2024-06-22 22:12:20,519] Trial 0 finished with value: 0.5368077000766498 and parameters: {'randomforestclassifier__n_estimators': 100, 'randomforestclassifier__max_features': 'sqrt', 'randomforestclassifier__max_depth': 100, 'randomforestclassifier__criterion': 'gini', 'randomforestclassifier__max_leaf_nodes': 1000, 'randomforestclassifier__bootstrap': True}. Best is trial 0 with value: 0.5368077000766498.
# [I 2024-06-22 22:12:34,485] Trial 1 finished with value: 0.5520892489111395 and parameters: {'randomforestclassifier__n_estimators': 997, 'randomforestclassifier__max_features': 'log2', 'randomforestclassifier__max_depth': 11, 'randomforestclassifier__criterion': 'entropy', 'randomforestclassifier__max_leaf_nodes': 46, 'randomforestclassifier__bootstrap': True}. Best is trial 1 with value: 0.5520892489111395.
# ...

# %%
import classifiers.rf as rf

list_param = [{'randomforestclassifier__n_estimators': 990, 'randomforestclassifier__max_features': 'log2', 'randomforestclassifier__max_depth': 10, 'randomforestclassifier__criterion': 'entropy', 'randomforestclassifier__max_leaf_nodes': 238, 'randomforestclassifier__bootstrap': True},
              {'randomforestclassifier__n_estimators': 997, 'randomforestclassifier__max_features': 'log2', 'randomforestclassifier__max_depth': 11, 'randomforestclassifier__criterion': 'entropy', 'randomforestclassifier__max_leaf_nodes': 46, 'randomforestclassifier__bootstrap': True}]
gs, model = rf.find_best_param_rf(X_train, y_train, n_trials=100, timeout=300, list_param=list_param)
# Out:
# [I 2024-06-22 22:27:41,606] A new study created in memory with name: no-name-62dfd032-e02b-4abd-83b8-7115ef683768
# [I 2024-06-22 22:27:45,393] Trial 0 finished with value: 0.5368077000766498 and parameters: {'randomforestclassifier__n_estimators': 100, 'randomforestclassifier__max_features': 'sqrt', 'randomforestclassifier__max_depth': 100, 'randomforestclassifier__criterion': 'gini', 'randomforestclassifier__max_leaf_nodes': 1000, 'randomforestclassifier__bootstrap': True}. Best is trial 0 with value: 0.5368077000766498.
# [I 2024-06-22 22:27:59,163] Trial 1 finished with value: 0.5520892489111395 and parameters: {'randomforestclassifier__n_estimators': 997, 'randomforestclassifier__max_features': 'log2', 'randomforestclassifier__max_depth': 11, 'randomforestclassifier__criterion': 'entropy', 'randomforestclassifier__max_leaf_nodes': 46, 'randomforestclassifier__bootstrap': True}. Best is trial 1 with value: 0.5520892489111395.
# ...

# %%
import classifiers.rf as rf

param = {'randomforestclassifier__n_estimators': 997, 'randomforestclassifier__max_features': 'log2', 'randomforestclassifier__max_depth': 11, 'randomforestclassifier__criterion': 'entropy', 'randomforestclassifier__max_leaf_nodes': 46, 'randomforestclassifier__bootstrap': True}
param = {k: [v] for k,v in param.items()}
_,_ = rf.fit_train_rf(X_train, y_train, param)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END randomforestclassifier__bootstrap=True, randomforestclassifier__criterion=entropy, randomforestclassifier__max_depth=11, randomforestclassifier__max_features=log2, randomforestclassifier__max_leaf_nodes=46, randomforestclassifier__n_estimators=997; total time=   5.1s
# [CV] END randomforestclassifier__bootstrap=True, randomforestclassifier__criterion=entropy, randomforestclassifier__max_depth=11, randomforestclassifier__max_features=log2, randomforestclassifier__max_leaf_nodes=46, randomforestclassifier__n_estimators=997; total time=   4.6s
# [CV] END randomforestclassifier__bootstrap=True, randomforestclassifier__criterion=entropy, randomforestclassifier__max_depth=11, randomforestclassifier__max_features=log2, randomforestclassifier__max_leaf_nodes=46, randomforestclassifier__n_estimators=997; total time=   4.7s
# ...

# %%
import classifiers.lgbm as lgbm

param = {'lgbmclassifier__num_leaves': 111, 'lgbmclassifier__min_data_in_leaf': 68, 'lgbmclassifier__max_depth': 12, 'lgbmclassifier__learning_rate': 0.29022421799586245, 'lgbmclassifier__n_estimators': 15, 'lgbmclassifier__subsample': 0.741248691753054, 'lgbmclassifier__colsample_bytree': 0.6811440489151888, 'lgbmclassifier__reg_alpha': 6.06289199034024, 'lgbmclassifier__reg_lambda': 6.6771927088523215, 'lgbmclassifier__boosting': 'dart'}
param = {k: [v] for k,v in param.items()}
_,_ = lgbm.fit_train_lgbm(X_train, y_train, param)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END lgbmclassifier__boosting=dart, lgbmclassifier__colsample_bytree=0.6811440489151888, lgbmclassifier__learning_rate=0.29022421799586245, lgbmclassifier__max_depth=12, lgbmclassifier__min_data_in_leaf=68, lgbmclassifier__n_estimators=15, lgbmclassifier__num_leaves=111, lgbmclassifier__reg_alpha=6.06289199034024, lgbmclassifier__reg_lambda=6.6771927088523215, lgbmclassifier__subsample=0.741248691753054; total time=   0.1s
# [CV] END lgbmclassifier__boosting=dart, lgbmclassifier__colsample_bytree=0.6811440489151888, lgbmclassifier__learning_rate=0.29022421799586245, lgbmclassifier__max_depth=12, lgbmclassifier__min_data_in_leaf=68, lgbmclassifier__n_estimators=15, lgbmclassifier__num_leaves=111, lgbmclassifier__reg_alpha=6.06289199034024, lgbmclassifier__reg_lambda=6.6771927088523215, lgbmclassifier__subsample=0.741248691753054; total time=   0.0s
# ...
